# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec
import os


def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev)


X = tf.placeholder(tf.float32, shape=[None, 784])

D_W1 = tf.Variable(xavier_init([784, 128]))
D_b1 = tf.Variable(tf.zeros(shape=[128]))

D_W2 = tf.Variable(xavier_init([128, 1]))
D_b2 = tf.Variable(tf.zeros(shape=[1]))

theta_D = [D_W1, D_W2, D_b1, D_b2]


Z = tf.placeholder(tf.float32, shape=[None, 100])

G_W1 = tf.Variable(xavier_init([100, 128]))
G_b1 = tf.Variable(tf.zeros(shape=[128]))

G_W2 = tf.Variable(xavier_init([128, 784]))
G_b2 = tf.Variable(tf.zeros(shape=[784]))

theta_G = [G_W1, G_W2, G_b1, G_b2]


DC_D_W1 = tf.Variable(xavier_init([5, 5, 1, 16]))
DC_D_b1 = tf.Variable(tf.zeros(shape=[16]))

DC_D_W2 = tf.Variable(xavier_init([3, 3, 16, 32]))
DC_D_b2 = tf.Variable(tf.zeros(shape=[32]))

DC_D_W3 = tf.Variable(xavier_init([7 * 7 * 32, 128]))
DC_D_b3 = tf.Variable(tf.zeros(shape=[128]))

DC_D_W4 = tf.Variable(xavier_init([128, 1]))
DC_D_b4 = tf.Variable(tf.zeros(shape=[1]))

theta_DC_D = [DC_D_W1, DC_D_b1, DC_D_W2, DC_D_b2, DC_D_W3, DC_D_b3, DC_D_W4, DC_D_b4]


def sample_Z(m, n):
    return np.random.uniform(-1., 1., size=[m, n])


def generator(z):
    G_h1 = tf.nn.relu(tf.matmul(z, G_W1) + G_b1)
    G_log_prob = tf.matmul(G_h1, G_W2) + G_b2
    G_prob = tf.nn.sigmoid(G_log_prob)

    return G_prob


def discriminator(x):
    D_h1 = tf.nn.relu(tf.matmul(x, D_W1) + D_b1)
    D_logit = tf.matmul(D_h1, D_W2) + D_b2
    D_prob = tf.nn.sigmoid(D_logit)

    return D_prob, D_logit


def dc_generator(z):
    pass


def dc_discriminator(x):
    x = tf.reshape(x, shape=[-1, 28, 28, 1])
    conv1 = tf.nn.relu(tf.nn.conv2d(x, DC_D_W1, strides=[1, 2, 2, 1], padding='SAME') + DC_D_b1)
    conv2 = tf.nn.relu(tf.nn.conv2d(conv1, DC_D_W2, strides=[1, 2, 2, 1], padding='SAME') + DC_D_b2)
    conv2 = tf.reshape(conv2, shape=[-1, 7 * 7 * 32])
    h = tf.nn.relu(tf.matmul(conv2, DC_D_W3) + DC_D_b3)
    logit = tf.matmul(h, DC_D_W4) + DC_D_b4
    prob = tf.nn.sigmoid(logit)

    return prob, logit


# def plot(samples):
#     fig = plt.figure(figsize=(4, 4))
#     gs = gridspec.GridSpec(4, 4)
#     gs.update(wspace=0.05, hspace=0.05)

#     for i, sample in enumerate(samples):
#         ax = plt.subplot(gs[i])
#         plt.axis('off')
#         ax.set_xticklabels([])
#         ax.set_yticklabels([])
#         ax.set_aspect('equal')
#         plt.imshow(sample.reshape(28, 28), cmap='Greys_r')

#     return fig


G_sample = generator(Z)
D_real, D_logit_real = dc_discriminator(X)
D_fake, D_logit_fake = dc_discriminator(G_sample)

# D_loss = -tf.reduce_mean(tf.log(D_real) + tf.log(1. - D_fake))
# G_loss = -tf.reduce_mean(tf.log(D_fake))

# Alternative losses:
# -------------------
D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(D_logit_real, tf.ones_like(D_logit_real)))
D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(D_logit_fake, tf.zeros_like(D_logit_fake)))
D_loss = D_loss_real + D_loss_fake
G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(D_logit_fake, tf.ones_like(D_logit_fake)))

D_solver = tf.train.AdamOptimizer().minimize(D_loss, var_list=theta_DC_D)
G_solver = tf.train.AdamOptimizer().minimize(G_loss, var_list=theta_G)

mb_size = 128
Z_dim = 100

mnist = input_data.read_data_sets('../data/MNIST_data', one_hot=True)

sess = tf.Session()
sess.run(tf.initialize_all_variables())

if not os.path.exists('../out/'):
    os.makedirs('../out/')

i = 0

for it in range(1000000):
    if it % 100 == 0:
        samples = sess.run(G_sample, feed_dict={Z: sample_Z(16, Z_dim)})

#         fig = plot(samples)
#         plt.savefig('../out/{}.png'.format(str(i).zfill(3)), bbox_inches='tight')
#         i += 1
#         plt.close(fig)

    X_mb, _ = mnist.train.next_batch(mb_size)

    _, D_loss_curr = sess.run([D_solver, D_loss], feed_dict={X: X_mb, Z: sample_Z(mb_size, Z_dim)})
    _, G_loss_curr = sess.run([G_solver, G_loss], feed_dict={Z: sample_Z(mb_size, Z_dim)})

    if it % 100 == 0:
        print('Iter: {}'.format(it))
        print('D loss: {:.4}'. format(D_loss_curr))
        print('G_loss: {:.4}'.format(G_loss_curr))
        print()
# Out:
# Extracting ../data/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../data/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../data/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-1-6113c8127d51>:127 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Iter: 0
# D loss: 15.48
# G_loss: 23.91
#
# Iter: 100
# D loss: 6.653e-06
# G_loss: 26.08
#
# Iter: 200
# D loss: 1.179e-07
# G_loss: 20.92
#
# Iter: 300
# D loss: 1.643e-05
# G_loss: 45.31
#
# Iter: 400
# D loss: 0.0005797
# G_loss: 39.78
#
# Iter: 500
# D loss: 1.77e-08
# G_loss: 24.0
#
# Iter: 600
# D loss: 0.0004878
# G_loss: 30.2
#
# Iter: 700
# D loss: 3.891e-12
# G_loss: 100.2
#
# Iter: 800
# D loss: 3.386e-08
# G_loss: 37.16
#
# Iter: 900
# D loss: 0.2469
# G_loss: 54.49
#
# Iter: 1000
# D loss: 3.503e-10
# G_loss: 41.09
#
# Iter: 1100
# D loss: 9.065e-07
# G_loss: 38.26
#
# Iter: 1200
# D loss: 8.486e-13
# G_loss: 103.3
#
# Iter: 1300
# D loss: 0.0008151
# G_loss: 38.87
#
# Iter: 1400
# D loss: 0.09953
# G_loss: 52.59
#
# Iter: 1500
# D loss: 2.56e-07
# G_loss: 67.43
#
# Iter: 1600
# D loss: 0.002573
# G_loss: 23.77
#
# Iter: 1700
# D loss: 4.959e-11
# G_loss: 31.62
#
# Iter: 1800
# D loss: 3.525e-16
# G_loss: 65.55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6113c8127d51> in <module>()
#     136         samples = sess.run(G_sample, feed_dict={Z: sample_Z(16, Z_dim)})
#     137
# --> 138         fig = plot(samples)
#     139         plt.savefig('../out/{}.png'.format(str(i).zfill(3)), bbox_inches='tight')
#     140         i += 1
#
# <ipython-input-1-6113c8127d51> in plot(samples)
#      94         ax = plt.subplot(gs[i])
#      95         plt.axis('off')
# ---> 96         ax.set_xticklabels([])
#      97         ax.set_yticklabels([])
#      98         ax.set_aspect('equal')
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in set_xticklabels(self, labels, fontdict, minor, **kwargs)
#    2907             kwargs.update(fontdict)
#    2908         ret = self.xaxis.set_ticklabels(labels,
# -> 2909                                         minor=minor, **kwargs)
#    2910         self.stale = True
#    2911         return ret
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, *args, **kwargs)
#    1569         else:
#    1570             self.set_major_formatter(mticker.FixedFormatter(ticklabels))
# -> 1571             ticks = self.get_major_ticks()
#    1572         ret = []
#    1573         for tick_label, tick in zip(ticklabels, ticks):
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1294             # update the new tick label properties from the old
#    1295             for i in range(numticks - len(self.majorTicks)):
# -> 1296                 tick = self._get_tick(major=True)
#    1297                 self.majorTicks.append(tick)
#    1298
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     400                           linestyle='None', marker=self._tickmarkers[0],
#     401                           markersize=self._size,
# --> 402                           markeredgewidth=self._width, zorder=self._zorder)
#     403         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     404         self._set_artist_props(l)
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     351         self._color = None
#     352         self.set_color(color)
# --> 353         self._marker = MarkerStyle()
#     354         self.set_marker(marker)
#     355
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     169         # _recache() in set_marker.
#     170         self._fillstyle = fillstyle
# --> 171         self.set_marker(marker)
#     172         self.set_fillstyle(fillstyle)
#     173
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     253
#     254         self._marker = marker
# --> 255         self._recache()
#     256
#     257     def get_path(self):
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/markers.py in _recache(self)
#     184     def _recache(self):
#     185         self._path = Path(np.empty((0, 2)))
# --> 186         self._transform = IdentityTransform()
#     187         self._alt_path = None
#     188         self._alt_transform = None
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1639
#    1640     def __init__(self, *args, **kwargs):
# -> 1641         Transform.__init__(self, *args, **kwargs)
#    1642         self._inverted = None
#    1643
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, shorthand_name)
#      96         # parents are deleted, references from the children won't keep
#      97         # them alive.
# ---> 98         self._parents = WeakValueDictionary()
#      99
#     100         # TransformNodes start out as invalid until their values are
#
# /Users/rileyedmunds/anaconda3/lib/python3.5/weakref.py in __init__(*args, **kw)
#     106         if len(args) > 1:
#     107             raise TypeError('expected at most 1 arguments, got %d' % len(args))
# --> 108         def remove(wr, selfref=ref(self)):
#     109             self = selfref()
#     110             if self is not None:
#
# KeyboardInterrupt:
